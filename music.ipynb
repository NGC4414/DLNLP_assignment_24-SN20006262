# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("./Datasets/lyrics/song_lyrics.csv")

# %%
df
# Out:
#                      title      tag                    artist  year   views  \
# 0                Killa Cam      rap                   Cam'ron  2004  173166
# 1               Can I Live      rap                     JAY-Z  1996  468624
# 2        Forgive Me Father      rap                  Fabolous  2003    4743
# 3             Down and Out      rap                   Cam'ron  2004  144404
# 4                   Fly In      rap                 Lil Wayne  2005   78271
# ...                    ...      ...                       ...   ...     ...
# 5134851              Ocean      pop                   Effemar  2022       3
# 5134852            64 Bars      rap                    Rapido  2022       4
# 5134853    Raise Our Hands      pop  Culture Code, Pag & Mylo  2016       3
# 5134854                CEO      rap               Antropolita  2022       5
# 5134855         New Number  country         Alana Springsteen  2022       1
#
#                                              features  \
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# Let's say you want to sample 1000 rows from your DataFrame
sampled_df = df.sample(n=3000, random_state=42)

# If you want to sample a fraction of your DataFrame instead, for example, 10%
sampled_df_fraction = df.sample(frac=0.1, random_state=42)

# Display the first few rows of the sampled DataFrame
#print(sampled_df.head())
sampled_df
# Out:
#                                    title   tag                     artist  \
# 862214              Words In Heaven Lost   pop  The Machine In The Garden
# 1251146                           Litany   pop            Society Burning
# 2150254                      UMENIKAMATA    rb                   Juma jux
# 2444508               An Overdose of Fun  rock               Liver Killer
# 89016                         Blown Away   rap                     Saigon
# ...                                  ...   ...                        ...
# 1951724                       Gian Marco   rap               Mondo Marcio
# 4802366          Charm Spanglish Edition   pop               Destinybratz
# 3822617                          January   pop             Billy La Signy
# 2561267                             Work   rap                      H3NRY
# 4440123  Carolina Pride explicit version   rap                   N.O.M.B.
#
#          year  views                         features  \
# ...

# %%
len(df)
# Out:
# 5134856

# %%
#Subset Stratifying
group_sizes = df['tag'].value_counts(normalize=True)

total_samples = 100000
samples_per_group = (group_sizes * total_samples).round().astype(int)

subset_df = pd.DataFrame() 

for group, size in samples_per_group.items():
    group_sample = df[df['tag'] == group].sample(n=size, replace=True)
    subset_df = pd.concat([subset_df, group_sample])

subset_df.head()
# Out:
#                                                 title  tag  \
# 4931060                                        Change  pop
# 3824963  Gabby Barrett - I hope Traducción al español  pop
# 2158666                                 Tu che ne 6ai  pop
# 733688                                 Ghetto Romance  pop
# 2587639                                     Slow Down  pop
#
#                                 artist  year  views  \
# 4931060                 FluffyEnderPug  2020      1
# 3824963  Genius Traducciones al Espaol  2019    465
# 2158666                          Pop X  2014     54
# 733688                          Damage  2001   2921
# 2587639                   Common Kings  2018   2121
#
#                                    features  \
# 4931060                                  {}
# 3824963  {"Genius Traducciones al Español"}
# 2158666                                  {}
# 733688                                   {}
# 2587639                                  {}
#
# ...

# %%
def clean_lyrics(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text

#df['cleaned_lyrics'] = df['lyrics'].apply(clean_lyrics)
subset_df['cleaned_lyrics'] = subset_df['lyrics'].apply(clean_lyrics)
print(subset_df['cleaned_lyrics'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 10
#       7     return text
#       9 #df['cleaned_lyrics'] = df['lyrics'].apply(clean_lyrics)
# ---> 10 subset_df['cleaned_lyrics'] = subset_df['lyrics'].apply(clean_lyrics)
#      11 print(subset_df['cleaned_lyrics'])
#
# File c:\Users\clara\anaconda3\envs\cuda_env\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
# ...
